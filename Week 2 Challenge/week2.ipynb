# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("vgsales-12-4-2019.csv")

df.head()
# Out:
#    Rank                           Name                      basename  \
# 0     1                     Wii Sports                    wii-sports
# 1     2              Super Mario Bros.              super-mario-bros
# 2     3                 Mario Kart Wii                mario-kart-wii
# 3     4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5              Wii Sports Resort             wii-sports-resort
#
#       Genre ESRB_Rating Platform         Publisher         Developer  \
# 0    Sports           E      Wii          Nintendo      Nintendo EAD
# 1  Platform         NaN      NES          Nintendo      Nintendo EAD
# 2    Racing           E      Wii          Nintendo      Nintendo EAD
# 3   Shooter         NaN       PC  PUBG Corporation  PUBG Corporation
# 4    Sports           E      Wii          Nintendo      Nintendo EAD
#
#    VGChartz_Score  Critic_Score  ...  NA_Sales  PAL_Sales  JP_Sales  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55792 entries, 0 to 55791
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            55792 non-null  int64
#  1   Name            55792 non-null  object
#  2   basename        55792 non-null  object
#  3   Genre           55792 non-null  object
#  4   ESRB_Rating     23623 non-null  object
#  5   Platform        55792 non-null  object
#  6   Publisher       55792 non-null  object
#  7   Developer       55775 non-null  object
#  8   VGChartz_Score  0 non-null      float64
#  9   Critic_Score    6536 non-null   float64
#  10  User_Score      335 non-null    float64
#  11  Total_Shipped   1827 non-null   float64
#  12  Global_Sales    19415 non-null  float64
#  13  NA_Sales        12964 non-null  float64
#  14  PAL_Sales       13189 non-null  float64
#  15  JP_Sales        7043 non-null   float64
#  16  Other_Sales     15522 non-null  float64
# ...

# %%
df.describe()
# Out:
#                Rank  VGChartz_Score  Critic_Score  User_Score  Total_Shipped  \
# count  55792.000000             0.0   6536.000000  335.000000    1827.000000
# mean   27896.500000             NaN      7.213709    8.253433       1.887258
# std    16105.907446             NaN      1.454079    1.401489       4.195693
# min        1.000000             NaN      1.000000    2.000000       0.030000
# 25%    13948.750000             NaN      6.400000    7.800000       0.200000
# 50%    27896.500000             NaN      7.500000    8.500000       0.590000
# 75%    41844.250000             NaN      8.300000    9.100000       1.800000
# max    55792.000000             NaN     10.000000   10.000000      82.860000
#
#        Global_Sales      NA_Sales     PAL_Sales     JP_Sales   Other_Sales  \
# count  19415.000000  12964.000000  13189.000000  7043.000000  15522.000000
# mean       0.365503      0.275541      0.155263     0.110402      0.044719
# ...

# %%
df.head(10)
# Out:
#    Rank                                Name                      basename  \
# 0     1                          Wii Sports                    wii-sports
# 1     2                   Super Mario Bros.              super-mario-bros
# 2     3                      Mario Kart Wii                mario-kart-wii
# 3     4       PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5                   Wii Sports Resort             wii-sports-resort
# 5     6  Pokemon Red / Green / Blue Version                    pokmon-red
# 6     7               New Super Mario Bros.          new-super-mario-bros
# 7     8                              Tetris                        tetris
# 8     9           New Super Mario Bros. Wii      new-super-mario-bros-wii
# 9    10                           Minecraft                     minecraft
#
#           Genre ESRB_Rating Platform         Publisher              Developer  \
# ...

# %%
df.drop("img_url", axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'basename', 'Genre', 'ESRB_Rating', 'Platform',
#        'Publisher', 'Developer', 'VGChartz_Score', 'Critic_Score',
#        'User_Score', 'Total_Shipped', 'Global_Sales', 'NA_Sales', 'PAL_Sales',
#        'JP_Sales', 'Other_Sales', 'Year', 'Last_Update', 'url', 'status',
#        'Vgchartzscore'],
#       dtype='object')

# %%
df.drop("url", axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'basename', 'Genre', 'ESRB_Rating', 'Platform',
#        'Publisher', 'Developer', 'VGChartz_Score', 'Critic_Score',
#        'User_Score', 'Total_Shipped', 'Global_Sales', 'NA_Sales', 'PAL_Sales',
#        'JP_Sales', 'Other_Sales', 'Year', 'Last_Update', 'status',
#        'Vgchartzscore'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55792 entries, 0 to 55791
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            55792 non-null  int64
#  1   Name            55792 non-null  object
#  2   basename        55792 non-null  object
#  3   Genre           55792 non-null  object
#  4   ESRB_Rating     23623 non-null  object
#  5   Platform        55792 non-null  object
#  6   Publisher       55792 non-null  object
#  7   Developer       55775 non-null  object
#  8   VGChartz_Score  0 non-null      float64
#  9   Critic_Score    6536 non-null   float64
#  10  User_Score      335 non-null    float64
#  11  Total_Shipped   1827 non-null   float64
#  12  Global_Sales    19415 non-null  float64
#  13  NA_Sales        12964 non-null  float64
#  14  PAL_Sales       13189 non-null  float64
#  15  JP_Sales        7043 non-null   float64
#  16  Other_Sales     15522 non-null  float64
# ...

# %%
df.drop("VGChartz_Score", axis=1, inplace=True)

# %%
df.drop("Total_Shipped", axis=1, inplace=True)

# %%
df.describe()
# Out:
#                Rank  Critic_Score  User_Score  Global_Sales      NA_Sales  \
# count  55792.000000   6536.000000  335.000000  19415.000000  12964.000000
# mean   27896.500000      7.213709    8.253433      0.365503      0.275541
# std    16105.907446      1.454079    1.401489      0.833022      0.512809
# min        1.000000      1.000000    2.000000      0.000000      0.000000
# 25%    13948.750000      6.400000    7.800000      0.030000      0.050000
# 50%    27896.500000      7.500000    8.500000      0.120000      0.120000
# 75%    41844.250000      8.300000    9.100000      0.360000      0.290000
# max    55792.000000     10.000000   10.000000     20.320000      9.760000
#
#           PAL_Sales     JP_Sales   Other_Sales          Year   status  \
# count  13189.000000  7043.000000  15522.000000  54813.000000  55792.0
# mean       0.155263     0.110402      0.044719   2005.659095      1.0
# std        0.399257     0.184673      0.129554      8.355585      0.0
# ...

# %%
df.head(10)
# Out:
#    Rank                                Name                      basename  \
# 0     1                          Wii Sports                    wii-sports
# 1     2                   Super Mario Bros.              super-mario-bros
# 2     3                      Mario Kart Wii                mario-kart-wii
# 3     4       PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5                   Wii Sports Resort             wii-sports-resort
# 5     6  Pokemon Red / Green / Blue Version                    pokmon-red
# 6     7               New Super Mario Bros.          new-super-mario-bros
# 7     8                              Tetris                        tetris
# 8     9           New Super Mario Bros. Wii      new-super-mario-bros-wii
# 9    10                           Minecraft                     minecraft
#
#           Genre ESRB_Rating Platform         Publisher              Developer  \
# ...

# %%
df.drop("status", axis=1, inplace=True)

# %%
df.drop("Last_Update", axis=1, inplace=True)

# %%
df["GlobalSales"] = df["Global_Sales"] + df["JP_Sales"] + df["NA_Sales"] + df["Other_Sales"] + df["PAL_Sales"]

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'basename', 'Genre', 'ESRB_Rating', 'Platform',
#        'Publisher', 'Developer', 'Critic_Score', 'User_Score', 'Global_Sales',
#        'NA_Sales', 'PAL_Sales', 'JP_Sales', 'Other_Sales', 'Year',
#        'Vgchartzscore', 'GlobalSales'],
#       dtype='object')

# %%
df.head(20)
# Out:
#     Rank                                Name                      basename  \
# 0      1                          Wii Sports                    wii-sports
# 1      2                   Super Mario Bros.              super-mario-bros
# 2      3                      Mario Kart Wii                mario-kart-wii
# 3      4       PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4      5                   Wii Sports Resort             wii-sports-resort
# 5      6  Pokemon Red / Green / Blue Version                    pokmon-red
# 6      7               New Super Mario Bros.          new-super-mario-bros
# 7      8                              Tetris                        tetris
# 8      9           New Super Mario Bros. Wii      new-super-mario-bros-wii
# 9     10                           Minecraft                     minecraft
# 10    11                           Duck Hunt                     duck-hunt
# ...

# %%
df.head(50)
# Out:
#     Rank                                          Name  \
# 0      1                                    Wii Sports
# 1      2                             Super Mario Bros.
# 2      3                                Mario Kart Wii
# 3      4                 PlayerUnknown's Battlegrounds
# 4      5                             Wii Sports Resort
# 5      6            Pokemon Red / Green / Blue Version
# 6      7                         New Super Mario Bros.
# 7      8                                        Tetris
# 8      9                     New Super Mario Bros. Wii
# 9     10                                     Minecraft
# 10    11                                     Duck Hunt
# 11    12                                      Wii Play
# 12    13                            Kinect Adventures!
# 13    14                                    Nintendogs
# 14    15                                 Mario Kart DS
# 15    16                 Pokemon Gold / Silver Version
# ...

# %%
clean_df = df.dropna(subset=["Global_Sales"])

# %%
clean_df.head(10)
# Out:
#     Rank                            Name                       basename  \
# 19    20              Grand Theft Auto V             grand-theft-auto-v
# 20    21              Grand Theft Auto V             grand-theft-auto-v
# 30    31     Grand Theft Auto: Vice City     grand-theft-auto-vice-city
# 32    33              Grand Theft Auto V             grand-theft-auto-v
# 34    35       Call of Duty: Black Ops 3       call-of-duty-black-ops-3
# 40    41  Call of Duty: Modern Warfare 3  call-of-duty-modern-warfare-3
# 41    42         Call of Duty: Black Ops         call-of-duty-black-ops
# 45    46           Red Dead Redemption 2          red-dead-redemption-2
# 46    47      Call of Duty: Black Ops II      call-of-duty-black-ops-ii
# 47    48      Call of Duty: Black Ops II      call-of-duty-black-ops-ii
#
#                Genre ESRB_Rating Platform       Publisher       Developer  \
# 19            Action           M      PS3  Rockstar Games  Rockstar North
# ...

# %%
clean_df.drop("GlobalSales", axis=1, inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\3393518099.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.drop("GlobalSales", axis=1, inplace=True)

# %%
clean_df.head(10)
# Out:
#     Rank                            Name                       basename  \
# 19    20              Grand Theft Auto V             grand-theft-auto-v
# 20    21              Grand Theft Auto V             grand-theft-auto-v
# 30    31     Grand Theft Auto: Vice City     grand-theft-auto-vice-city
# 32    33              Grand Theft Auto V             grand-theft-auto-v
# 34    35       Call of Duty: Black Ops 3       call-of-duty-black-ops-3
# 40    41  Call of Duty: Modern Warfare 3  call-of-duty-modern-warfare-3
# 41    42         Call of Duty: Black Ops         call-of-duty-black-ops
# 45    46           Red Dead Redemption 2          red-dead-redemption-2
# 46    47      Call of Duty: Black Ops II      call-of-duty-black-ops-ii
# 47    48      Call of Duty: Black Ops II      call-of-duty-black-ops-ii
#
#                Genre ESRB_Rating Platform       Publisher       Developer  \
# 19            Action           M      PS3  Rockstar Games  Rockstar North
# ...

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19415 entries, 19 to 21241
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           19415 non-null  int64
#  1   Name           19415 non-null  object
#  2   basename       19415 non-null  object
#  3   Genre          19415 non-null  object
#  4   ESRB_Rating    13810 non-null  object
#  5   Platform       19415 non-null  object
#  6   Publisher      19415 non-null  object
#  7   Developer      19411 non-null  object
#  8   Critic_Score   4275 non-null   float64
#  9   User_Score     172 non-null    float64
#  10  Global_Sales   19415 non-null  float64
#  11  NA_Sales       12964 non-null  float64
#  12  PAL_Sales      13189 non-null  float64
#  13  JP_Sales       7043 non-null   float64
#  14  Other_Sales    15522 non-null  float64
#  15  Year           19377 non-null  float64
#  16  Vgchartzscore  451 non-null    float64
# ...

# %%
clean_df.describe()
# Out:
#                Rank  Critic_Score  User_Score  Global_Sales      NA_Sales  \
# count  19415.000000   4275.000000  172.000000  19415.000000  12964.000000
# mean   11157.572856      7.144023    8.276163      0.365503      0.275541
# std     6022.522160      1.430825    1.234666      0.833022      0.512809
# min       20.000000      1.000000    2.000000      0.000000      0.000000
# 25%     5916.500000      6.400000    7.900000      0.030000      0.050000
# 50%    11397.000000      7.400000    8.500000      0.120000      0.120000
# 75%    16386.500000      8.200000    9.100000      0.360000      0.290000
# max    21242.000000     10.000000   10.000000     20.320000      9.760000
#
#           PAL_Sales     JP_Sales   Other_Sales          Year  Vgchartzscore
# count  13189.000000  7043.000000  15522.000000  19377.000000     451.000000
# mean       0.155263     0.110402      0.044719   2007.640760       7.497339
# ...

# %%
clean_df["Critic_Score"].fillna(clean_df["Critic_Score"].mode()[0], inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\1657647916.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   clean_df["Critic_Score"].fillna(clean_df["Critic_Score"].mode()[0], inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\1657647916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19415 entries, 19 to 21241
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           19415 non-null  int64
#  1   Name           19415 non-null  object
#  2   basename       19415 non-null  object
#  3   Genre          19415 non-null  object
#  4   ESRB_Rating    13810 non-null  object
#  5   Platform       19415 non-null  object
#  6   Publisher      19415 non-null  object
#  7   Developer      19411 non-null  object
#  8   Critic_Score   19415 non-null  float64
#  9   User_Score     172 non-null    float64
#  10  Global_Sales   19415 non-null  float64
#  11  NA_Sales       12964 non-null  float64
#  12  PAL_Sales      13189 non-null  float64
#  13  JP_Sales       7043 non-null   float64
#  14  Other_Sales    15522 non-null  float64
#  15  Year           19377 non-null  float64
#  16  Vgchartzscore  451 non-null    float64
# ...

# %%
clean_df["User_Score"].fillna(clean_df["User_Score"].mode()[0], inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\2359800061.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   clean_df["User_Score"].fillna(clean_df["User_Score"].mode()[0], inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\2359800061.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19415 entries, 19 to 21241
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           19415 non-null  int64
#  1   Name           19415 non-null  object
#  2   basename       19415 non-null  object
#  3   Genre          19415 non-null  object
#  4   ESRB_Rating    13810 non-null  object
#  5   Platform       19415 non-null  object
#  6   Publisher      19415 non-null  object
#  7   Developer      19411 non-null  object
#  8   Critic_Score   19415 non-null  float64
#  9   User_Score     19415 non-null  float64
#  10  Global_Sales   19415 non-null  float64
#  11  NA_Sales       12964 non-null  float64
#  12  PAL_Sales      13189 non-null  float64
#  13  JP_Sales       7043 non-null   float64
#  14  Other_Sales    15522 non-null  float64
#  15  Year           19377 non-null  float64
#  16  Vgchartzscore  451 non-null    float64
# ...

# %%
clean_df.describe()
# Out:
#                Rank  Critic_Score    User_Score  Global_Sales      NA_Sales  \
# count  19415.000000  19415.000000  19415.000000  19415.000000  12964.000000
# mean   11157.572856      7.031713      8.002447      0.365503      0.275541
# std     6022.522160      0.673994      0.118730      0.833022      0.512809
# min       20.000000      1.000000      2.000000      0.000000      0.000000
# 25%     5916.500000      7.000000      8.000000      0.030000      0.050000
# 50%    11397.000000      7.000000      8.000000      0.120000      0.120000
# 75%    16386.500000      7.000000      8.000000      0.360000      0.290000
# max    21242.000000     10.000000     10.000000     20.320000      9.760000
#
#           PAL_Sales     JP_Sales   Other_Sales          Year  Vgchartzscore
# count  13189.000000  7043.000000  15522.000000  19377.000000     451.000000
# mean       0.155263     0.110402      0.044719   2007.640760       7.497339
# ...

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.histplot(clean_df['Critic_Score'], kde=False, bins=10, color='blue')
plt.title('Critic Score Histogram')

plt.subplot(1, 3, 2)
sns.histplot(clean_df['User_Score'], kde=False, bins=10, color='green')
plt.title('User Score Histogram')

plt.subplot(1, 3, 3)
sns.histplot(clean_df['Global_Sales'], kde=False, bins=10, color='red')
plt.title('Global Sales Histogram')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.kdeplot(clean_df['Critic_Score'], shade=True, color='blue')
plt.title('Critic Score Density Plot')

plt.subplot(1, 3, 2)
sns.kdeplot(clean_df['User_Score'], shade=True, color='green')
plt.title('User Score Density Plot')

plt.subplot(1, 3, 3)
sns.kdeplot(clean_df['Global_Sales'], shade=True, color='red')
plt.title('Global Sales Density Plot')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\976121730.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(clean_df['Critic_Score'], shade=True, color='blue')
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\976121730.py:11: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(clean_df['User_Score'], shade=True, color='green')
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\976121730.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(clean_df['Global_Sales'], shade=True, color='red')

# %%
clean_df.groupby("Genre")["Global_Sales"].sum().sort_values(ascending=False)
# Out:
# Genre
# Sports              1228.20
# Action              1206.82
# Shooter             1051.74
# Misc                 596.64
# Racing               547.71
# Role-Playing         502.12
# Platform             424.51
# Fighting             363.98
# Adventure            346.17
# Simulation           320.32
# Action-Adventure     155.45
# Strategy             144.22
# Puzzle               132.54
# Music                 52.81
# MMO                   11.86
# Party                  5.39
# Visual Novel           3.47
# Sandbox                1.89
# Board Game             0.31
# Education              0.09
# Name: Global_Sales, dtype: float64

# %%
fig = plt.figure(figsize= (10,10))

plt.bar(clean_df["Genre"], clean_df["Global_Sales"], width=0.5)

plt.xlabel("Genres")
plt.ylabel("Global Sales")
plt.title("Global Sales by Genre")

plt.show()

# %%
correlation_coefficient = clean_df["Critic_Score"].corr(clean_df["Global_Sales"])
correlation_coefficient
# Out:
# 0.25171417959941744

# %%
print(f"The correlation coefficient of {correlation_coefficient} is slightly correlated.")
# Out:
# The correlation coefficient of 0.25171417959941744 is slightly correlated.

# %%
clean_df.groupby("Year")["Global_Sales"].sum().sort_values(ascending=False)
# Out:
# Year
# 2008.0    574.65
# 2009.0    533.82
# 2010.0    474.62
# 2011.0    472.17
# 2007.0    455.62
# 2002.0    329.87
# 2005.0    325.89
# 2003.0    323.14
# 2014.0    304.36
# 2004.0    302.56
# 2012.0    295.51
# 2013.0    285.24
# 2006.0    273.64
# 2015.0    256.24
# 2001.0    244.80
# 2016.0    214.49
# 2017.0    209.14
# 1999.0    188.59
# 2000.0    180.53
# 2018.0    172.38
# 1998.0    165.35
# 1997.0    128.83
# 1996.0    108.45
# 1995.0     62.00
# 1994.0     37.63
# 1982.0     35.69
# 1983.0     22.68
# 1993.0     22.46
# 1992.0     10.63
# 1981.0     10.49
# 1986.0     10.37
# 1989.0      9.15
# 1990.0      9.07
# 1988.0      8.73
# 1991.0      6.33
# 1978.0      6.19
# 1987.0      5.59
# 1984.0      4.85
# 2020.0      3.20
# 1980.0      2.58
# 1977.0      2.50
# 2019.0      2.42
# 1985.0      2.19
# 1970.0      1.16
# 1979.0      0.31
# Name: Global_Sales, dtype: float64

# %%
fig = plt.figure(figsize= (10,10))

plt.bar(clean_df["Year"], clean_df["Global_Sales"], width=0.5)

plt.xlabel("Year")
plt.ylabel("Global Sales")
plt.title("Global Sales by Year")

plt.show()

# %%
clean_df["Year"].fillna(method='bfill', inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\1132585500.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   clean_df["Year"].fillna(method='bfill', inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\1132585500.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df["Year"].fillna(method='bfill', inplace=True)

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19415 entries, 19 to 21241
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           19415 non-null  int64
#  1   Name           19415 non-null  object
#  2   basename       19415 non-null  object
#  3   Genre          19415 non-null  object
#  4   ESRB_Rating    13810 non-null  object
#  5   Platform       19415 non-null  object
#  6   Publisher      19415 non-null  object
#  7   Developer      19411 non-null  object
#  8   Critic_Score   19415 non-null  float64
#  9   User_Score     19415 non-null  float64
#  10  Global_Sales   19415 non-null  float64
#  11  NA_Sales       12964 non-null  float64
#  12  PAL_Sales      13189 non-null  float64
#  13  JP_Sales       7043 non-null   float64
#  14  Other_Sales    15522 non-null  float64
#  15  Year           19415 non-null  float64
#  16  Vgchartzscore  451 non-null    float64
# ...

# %%
plt.figure(figsize=(10, 10))
plt.plot(clean_df['Year'], clean_df['Global_Sales'], marker='o', linestyle='-', color='b', label='Global Sales')
plt.title('Global Sales Over Time')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
plt.xticks(clean_df['Year'])
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19415 entries, 19 to 21241
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           19415 non-null  int64
#  1   Name           19415 non-null  object
#  2   basename       19415 non-null  object
#  3   Genre          19415 non-null  object
#  4   ESRB_Rating    13810 non-null  object
#  5   Platform       19415 non-null  object
#  6   Publisher      19415 non-null  object
#  7   Developer      19411 non-null  object
#  8   Critic_Score   19415 non-null  float64
#  9   User_Score     19415 non-null  float64
#  10  Global_Sales   19415 non-null  float64
#  11  NA_Sales       12964 non-null  float64
#  12  PAL_Sales      13189 non-null  float64
#  13  JP_Sales       7043 non-null   float64
#  14  Other_Sales    15522 non-null  float64
#  15  Year           19415 non-null  float64
#  16  Vgchartzscore  451 non-null    float64
# ...

# %%
clean_df.groupby(["Platform", "Genre"])["Global_Sales"].sum()
# Out:
# Platform  Genre
# 2600      Action          31.34
#           Adventure        1.30
#           Fighting         1.24
#           Misc             0.51
#           Platform        13.27
#                           ...
# XOne      Shooter         93.94
#           Simulation       3.48
#           Sports          48.80
#           Strategy         1.08
#           Visual Novel     0.02
# Name: Global_Sales, Length: 383, dtype: float64

# %%
sns.catplot(data=clean_df, y="Global_Sales", x="Genre", hue="Platform")

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Genre', y='Global_Sales', hue='Platform', data=clean_df)
plt.title('Distribution of Global Sales by Genre Across Platforms')
plt.xlabel('Genre')
plt.ylabel('Global Sales (in millions)')
plt.legend(title='Platform')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
x = clean_df[["Critic_Score", "User_Score"]]
y = clean_df["Global_Sales"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)

# %%
model = LinearRegression()

model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 0.35741369,  0.35741369, -0.73909845, ...,  0.35741369,
#         0.22841226,  0.35741369])

# %%
absolute_error = mean_absolute_error(y_test, y_pred)

square_error = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)

# %%
print(f"{absolute_error}, {square_error}, {r2}")
# Out:
# 0.40393965850872704, 0.662164728885155, 0.05420117746087216

# %%
plt.figure(figsize=(10, 6))

# Plot predicted vs actual values
plt.scatter(y_test, y_pred, color='blue', edgecolor='w', alpha=0.6)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', lw=2)
plt.xlabel('Actual Global Sales')
plt.ylabel('Predicted Global Sales')
plt.title('Actual vs. Predicted Global Sales')

plt.grid(True)
plt.show()
